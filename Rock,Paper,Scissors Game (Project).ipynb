# %%
import random
import getpass
print('Welcome to the Game \nRock   Paper   Scissors')
print('Enter Choice \n1.CPU \n2.PvP')
ask=int(input())
if ask==1:
#print game instructions
    print("Game Instructions are as follows: \n"+"Rock vs Paper ===> Paper Wins \n"+"Scissors vs Paper ===> Scissors Wins \n"+"Rock vs Scissors ===> Rock Wins \n")
    print('You just have to Enter the Choice NUMBER')
    while True:
        print("Enter Choice \n 1.Rock \n 2.Paper \n 3.Scissors")
        choice=int(input("Enter Choice Number: "))

    #asking for valid input
        while choice>3 and choice<1:
            choice=int(input('Enter Valid Input'))
    #take user choice
        if choice==1:
            choice_name='Rock'
        elif choice==2:
            choice_name='Paper'
        else:
            choice_name='Scissors'

    #print user choice
        print('\nUser Choice is:',choice_name)
        print('\nNow its Computers Turn ')

    #computer's turn using random
        comp_choice=random.randint(1,3)

    #checking for computer's turn and using random module if they are equal
        while comp_choice==choice:
            comp_choice=random.randint(1,3)

    #checking for loop conditions
        if comp_choice==1:
            comp_choice_name='Rock'
        elif comp_choice==2:
            comp_choice_name='Paper'
        else:
            comp_choice_name='Scissors'

        print('\nComputers Choice is: '+comp_choice_name)

        print(choice_name+' VS '+comp_choice_name)
    #condition for winning
        if ((choice==1 and comp_choice==2) or (choice==2 and comp_choice==1)):
            print('\n*Paper Wins*')
            result='Paper'
        elif ((choice==1 and comp_choice==3) or (choice==1 and comp_choice==3)):
            print("*\nRock Wins*")
            result='Rock'
        else:
            print('\n*Scissors Wins*')
            result='Scissors'
    #print who wins
        if result==choice_name:
            print('\nCongratulations you Won the game!')
        else:
            print('\nComputer Wins')

        #ask user if he wants to play again
        print("\nDo you want to play again? (Y/N)")
        ans=input()
        if ans =='n' or ans=='N':
            break
        
        
#PvP ask the users to enter input
if ask==2:
    print("Game Instructions are as follows: \n"+"Rock vs Paper ===> Paper Wins \n"+"Scissors vs Paper ===> Scissors Wins \n"+"Rock vs Scissors ===> Rock Wins \n")
    print('\nYou have to enter the choice in lower alphabets')
    while True:
        print("\nEnter Choice \n 1.Rock \n 2.Paper \n 3.Scissors")
        choice1=getpass.getpass(prompt="Player 1 \nEnter your Choice: ")
        choice2=getpass.getpass(prompt="Player 2 \nEnter your Choice: ")
    
   
    #take user choice
        if choice1=='rock':
            choice1_name='Rock'
        elif choice1=='paper':
            choice1_name='Paper'
        else:
            choice1_name='Scissors'
    
    #take user choice
        if choice2=='rock':
            choice2_name='Rock'
        elif choice2=='paper':
            choice2_name='Paper'
        else:
            choice2_name='Scissors'
    #print user choice
        print('\nPlayer 1 Choice is: ',choice1_name)
        print('\nPlayer 2 Choice is: ',choice2_name)
        print(choice1_name,'VS',choice2_name)
    #condition for winning
        
        if ((choice1=='rock' and choice2=='paper') or (choice1=='paper' and choice2=='rock')):
            print('\n*Paper Wins*')
            result='Paper'
        elif ((choice1=='rock' and choice2=='scissors') or (choice1=='scissors' and choice2=='rock')):
            print("\n*Rock Wins*")
            result='Rock'
        elif ((choice1=='scissors' and choice2=='paper') or (choice1=='rock' and choice2=='scissors')):
            print('\n*Scissors Wins*')
            result='Scissors'
        if choice1 == choice2:
            print('\nMatch Tied')
            continue
    #print who wins
        if result==choice1_name:
            print('\nPlayer 1 won the Game')
        else:
            print('\nPlayer 2 won the Game')
    #ask user if he wants to play again
        print("\nDo you want to play again? (Y/N)")
        ans=input()
        if ans =='n' or ans=='N':
            break

print('\nThanks For Playing')
print('\nGame Developed by: \nAyush \nRaman \nPrashant \nJatin \nRohit')
